# %%
import pandas as pd
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
import plotly.dashboard_objs as dashboard
import IPython.display
from IPython.display import Image
plotly.__version__
# Out:
# '3.6.1'

# %%
plotly.tools.set_credentials_file(username='irvinghg', api_key='1B3oHF0vwgLpowDqVAa7')

# %%
# Read CSV
results_m1 = pd.read_csv('../results/match1.csv')#,
                         #na_values=':', usecols=['qid', 'score', 'time', 'user_effort', 'calculated_effort', 'execution_time'])
results_m1
# Out:
#    qid  score  time user_effort  calculated_effort  execution_time
# 0    1    0.0     8     Regular                100        0.000025
# 1    2    0.0     0     Regular                100        0.000025
# 2    3    0.0     6         NaN                100        0.000025
# 3    4    0.0     0     Regular                100        0.000025
# 4    5    0.0     2     Regular                100        0.000025
# 5    6    0.0     0         NaN                100        0.000025
# 6    7    0.0     3     Regular                100        0.000025

# %%
results_m2 = pd.read_csv('../results/match2.csv')#,
                         #na_values=':', usecols=['qid', 'score', 'time', 'user_effort', 'calculated_effort', 'execution_time'])
results_m2
# Out:
#    qid  score  time user_effort  calculated_effort  execution_time
# 0    1    0.0     5     Regular         100.000000         0.00003
# 1    2    0.0     3     Regular         100.000000         0.00003
# 2    3    0.0     5     Regular         100.000000         0.00003
# 3    4    0.0     6         Low         100.000000         0.00003
# 4    5    0.0    20        High         100.000000         0.00003
# 5    6    1.0     2         Low           0.111111         0.00003
# 6    7    0.0    21         Low         100.000000         0.00003

# %%
r = list(results_m1['score'])
rmax=max(r)
deltar=rmax+(rmax*0.1)

r2 = list(results_m2['score'])
rmax2=max(r2)
deltar2=rmax2+(rmax2*0.1)

data = [go.Scatterpolar(
  r = r,
    theta = results_m1['qid'],
  fill = 'toself',
    name = 'Score Match 1'
),
    go.Scatterpolar(
      r = r2,
      theta = results_m2['qid'],
      fill = 'toself',
      name = 'Score Match 2'
    )
]

layout = go.Layout(
  polar = dict(
    radialaxis = dict(
      visible = True,
      range = [0, max(deltar,deltar2)]
    )
  ),
  showlegend = True
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename = "score-multiple")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~irvinghg/164.embed" height="525px" width="100%"></iframe>

# %%
plot_url_mult = py.plot(fig);plot_url_mult
# Out:
# ---------------------------------------------------------------------------
# PlotlyRequestError                        Traceback (most recent call last)
# <ipython-input-6-35f849b49687> in <module>()
# ----> 1 plot_url_mult = py.plot(fig);plot_url_mult
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/plotly/plotly/plotly.py in plot(figure_or_data, validate, **plot_options)
#     237     data = fig.get('data', [])
#     238     plot_options['layout'] = fig.get('layout', {})
# --> 239     response = v1.clientresp(data, **plot_options)
#     240
#     241     # Check if the url needs a secret key
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/plotly/api/v1/clientresp.py in clientresp(data, **kwargs)
#      33
#      34     url = '{plotly_domain}/clientresp'.format(**cfg)
# ---> 35     response = request('post', url, data=payload)
#      36
#      37     # Old functionality, just keeping it around.
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/retrying.py in wrapped_f(*args, **kw)
#      47             @six.wraps(f)
#      48             def wrapped_f(*args, **kw):
# ---> 49                 return Retrying(*dargs, **dkw).call(f, *args, **kw)
#      50
#      51             return wrapped_f
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/retrying.py in call(self, fn, *args, **kwargs)
#     204
#     205             if not self.should_reject(attempt):
# --> 206                 return attempt.get(self._wrap_exception)
#     207
#     208             delay_since_first_attempt_ms = int(round(time.time() * 1000)) - start_time
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/retrying.py in get(self, wrap_exception)
#     245                 raise RetryError(self)
#     246             else:
# --> 247                 six.reraise(self.value[0], self.value[1], self.value[2])
#     248         else:
#     249             return self.value
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/retrying.py in call(self, fn, *args, **kwargs)
#     198         while True:
#     199             try:
# --> 200                 attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     201             except:
#     202                 tb = sys.exc_info()
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/plotly/api/v1/utils.py in request(method, url, **kwargs)
#      88         content = response.content if response else 'No content'
#      89         raise exceptions.PlotlyRequestError(message, status_code, content)
# ---> 90     validate_response(response)
#      91     return response
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/plotly/api/v1/utils.py in validate_response(response)
#      38         message = content if content else 'No Content'
#      39
# ---> 40     raise exceptions.PlotlyRequestError(message, status_code, content)
#      41
#      42
#
# PlotlyRequestError: Account limit reached: Your account is limited to creating 25 charts. To continue, you can override or delete existing charts or you can upgrade your account at: https://plot.ly/products/cloud

# %%
data = [go.Scatterpolar(
  r = r,
    theta = results_m1['qid'],
  fill = 'toself',
    name = 'Time Match 1'
),
    go.Scatterpolar(
      r = r2,
      theta = results_m2['qid'],
      fill = 'toself',
      name = 'Time Match 2'
    )
]

trace1 = go.Bar(
    x = results_m1['qid'],
    y=results_m1['time'],
    name='Using raw data',
    marker=dict(
        color='rgb(55, 83, 109)'
    )
)
trace2 = go.Bar(
    x = results_m2['qid'],
    y = results_m2['time'],
    name='Using views',
    marker=dict(
        color='rgb(26, 118, 255)'
    )
)
data = [trace1, trace2]
layout = go.Layout(
    title='Time to answer challenge queries',
    xaxis=dict(
        tickfont=dict(
            size=14,
            color='rgb(107, 107, 107)'
        )
    ),
    yaxis=dict(
        title='Time (seconds)',
        titlefont=dict(
            size=16,
            color='rgb(107, 107, 107)'
        ),
        tickfont=dict(
            size=14,
            color='rgb(107, 107, 107)'
        )
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15,
    bargroupgap=0.1
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='question-time-bar')

# %%
plot_url_bar = py.plot(fig);plot_url_bar

# %%
effort_groups1 = results_m1.groupby('user_effort').count().qid;effort_groups1

# %%
effort_groups2 = results_m2.groupby('user_effort').count().qid;effort_groups2

# %%
# User effor --pie chart--
fig = {
    "data": [
        {
            "values": effort_groups1,
            "labels": ['Low','Regular','High'],
            "marker": {
                "line": {
                    "color": "#FFFFFF",
                    "width": 2
                    },
                "colors": [
                    "rgb(178, 62, 39)",
                    "rgb(119, 123, 132)",
                    "rgb(21, 52, 140)"
                    ]
                    },
            "insidetextfont": {
                "color": "#FFFFFF"
                },
            #"domain": {"x": [0, .48]},
            "name": "User Effort Group",
            "hoverinfo":"label+percent+name",
            "hole": .4,
            "type": "pie"
        }],
    "layout": {
            "title":"User effort perception exploring raw data",
            "annotations": [
                {
                    "font": {
                        "size": 20
                    },
                    "showarrow": False,
                    "text": "Match 1",
                    "x": 0.5,
                    "y": 0.5
                }
            ]
        }
     
}

py.iplot(fig, filename='userEffort_donut_m1')

# %%
plot_url_donut1 = py.plot(fig);plot_url_donut1

# %%
# User effor --pie chart--
fig = {
    "data": [
        {
            "values": effort_groups2,
            "labels": ['Low','Regular','High'],
            "marker": {
                "line": {
                    "color": "#FFFFFF",
                    "width": 2
                    },
                "colors": [
                    "rgb(178, 62, 39)",
                    "rgb(119, 123, 132)",
                    "rgb(21, 52, 140)"
                    ]
                    },
            "insidetextfont": {
                "color": "#FFFFFF"
                },
            #"domain": {"x": [0, .48]},
            "name": "User Effort Group",
            "hoverinfo":"label+percent+name",
            "hole": .4,
            "type": "pie"
        }],
    "layout": {
            "title":"User effort perception exploring views",
            "annotations": [
                {
                    "font": {
                        "size": 20
                    },
                    "showarrow": False,
                    "text": "Match 2",
                    "x": 0.5,
                    "y": 0.5
                }
            ]
        }
     
}

py.iplot(fig, filename='userEffort_donut_m2')

# %%
plot_url_donut2 = py.plot(fig);plot_url_donut2

# %%
# Line and Scatter Plots
plotly.tools.set_credentials_file(username='irvinghg', api_key='1B3oHF0vwgLpowDqVAa7')

# Create traces
trace0 = go.Scatter(
    x = results_m1['qid'],
    y = results_m1['calculated_effort'],
    mode = 'lines+markers',
    name = 'Exploring raw data'
)
trace1 = go.Scatter(
    x = results_m2['qid'],
    y = results_m2['calculated_effort'],
    mode = 'lines+markers',
    name = 'Exploring views'
)

layout = dict(title = 'Calculated effort (time/core ratio)',
              yaxis = dict(zeroline = False),
              xaxis = dict(zeroline = False)
             )

data = [trace0, trace1]
fig = dict(data=data, layout=layout)

py.iplot(fig, filename='calculatedEffort_Scattered')

# %%
plot_url_calc = py.plot(fig);plot_url_calc

# %%
print(plot_url_bar)
print(plot_url_calc)
print(plot_url_mult)
print(plot_url_donut1)
print(plot_url_donut2)

# %%
my_dboard = dashboard.Dashboard()
my_dboard.get_preview()

box_1 = {
    'type': 'box',
    'boxType': 'plot',
    'fileId': 'irvinghg:'+ plot_url_bar.rsplit('/', 1)[-1],
    'title': 'question-time-bar'
}

box_2 = {
    'type': 'box',
    'boxType': 'plot',
    'fileId': 'irvinghg:'+ plot_url_calc.rsplit('/', 1)[-1],
    'title': 'calculatedEffort_Scattered'
}

box_3 = {
    'type': 'box',
    'boxType': 'plot',
    'fileId': 'irvinghg:'+ plot_url_mult.rsplit('/', 1)[-1],
    'title': 'score-multiple'
}

box_4 = {
    'type': 'box',
    'boxType': 'plot',
    'fileId': 'irvinghg:'+ plot_url_donut1.rsplit('/', 1)[-1],
    'title': 'userEffort_donut_m1'
}
 
box_5 = {
    'type': 'box',
    'boxType': 'plot',
    'fileId': 'irvinghg:'+ plot_url_donut2.rsplit('/', 1)[-1],
    'title': 'userEffort_donut_m2'
}
 

my_dboard.insert(box_2)             # scattered
my_dboard.insert(box_1, 'above', 1) # time bar
my_dboard.insert(box_4, 'below', 2) # donut 1
my_dboard.insert(box_5, 'right', 3) # donut 2
my_dboard.insert(box_3, 'right', 2) # multiple


py.dashboard_ops.upload(my_dboard, 'game-dash1000')

# %%
print(py.dashboard_ops.upload(my_dboard, 'game-dash1000'))
